# %%
import pandas as pd
import numpy as np

df = pd.read_excel('postos.xlsx', sheet_name='Base_22.04.25')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45237 entries, 0 to 45236
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CODIGOISIMP       45237 non-null  int64
#  1   AUTORIZACAO       45236 non-null  object
#  2   DATAPUBLICACAO    45236 non-null  object
#  3   RAZAOSOCIAL       45237 non-null  object
#  4   CNPJ              45237 non-null  int64
#  5   ENDERECO          45237 non-null  object
#  6   COMPLEMENTO       13054 non-null  object
#  7   BAIRRO            45103 non-null  object
#  8   CEP               45237 non-null  object
#  9   UF                45237 non-null  object
#  10  MUNICIPIO         45237 non-null  object
#  11  BANDEIRA          45237 non-null  object
#  12  BANDEIRA TRATADA  45237 non-null  object
#  13  DATAVINCULACAO    45236 non-null  object
#  14  PLACE ID          2997 non-null   object
#  15  Unnamed: 15       422 non-null    float64
# ...

# %%
df_filtered = df.iloc[:,:15]
df_filtered = df_filtered[df_filtered['BANDEIRA'] == 'RAIZEN']
df_filtered
# Out:
#        CODIGOISIMP   AUTORIZACAO       DATAPUBLICACAO  \
# 6          1017635  PR/AL0015680  2001-10-19 00:00:00
# 57         1015669  PR/BA0014750  2001-08-30 00:00:00
# 62         1052321  AV/BA0208696  2007-02-28 00:00:00
# 76         1055986  PR/CE0212942  2007-05-24 00:00:00
# 82         1019474  PR/CE0007179  2001-04-24 00:00:00
# ...            ...           ...                  ...
# 45118      1305088  PR/RS0248072  2024-10-24 00:00:00
# 45166      1307812  PR/PA0249050  2025-02-14 00:00:00
# 45178      1307700  PR/MT0249003  2025-02-11 00:00:00
# 45180      1308054  PR/SP0249128  2025-02-25 00:00:00
# 45222      1302143  PR/SP0246983  2024-06-12 00:00:00
#
#                                              RAZAOSOCIAL            CNPJ  \
# 6                    REVCOM-REVENDA DE COMBUSTIVEIS LTDA  24322380000149
# 57                              AUTO POSTO BUDIÃƒO LTDA.  13635461000182
# 62     MACTRA COMÃ‰RCIO DE COMBUSTÃVEIS E LUBRIFICAN...   1630610000131
# ...

# %%
df_filtered['RAZAOSOCIAL'].isna().sum()
# Out:
# 0

# %%
# Create a new table with PLACE ID and RAZAOSOCIAL, removing null values
place_razao_table = df_filtered[['PLACE ID ', 'RAZAOSOCIAL']].dropna()
place_razao_table
# Out:
#                          PLACE ID   \
# 6      ChIJ7T9lvKKkBgcR76Im1Vta5sw
# 57     ChIJNfsZ_rhXuAARjNK8xskk1zU
# 62                         INVALID
# 76     ChIJeQ2XB7Tb6wcRWAI7TZNmNTc
# 82     ChIJPwX3JAbH6gcRwPCnxseWv1M
# ...                            ...
# 30275  ChIJY5YTTdsduAARmOEbN5_Eams
# 30284  ChIJj8i-RrX6PpMRZTW0Fd58js8
# 30285  ChIJd-VcCmqPpgARZqU_N8BHfS8
# 30313  ChIJs7qojaIrPgcRny64Fsnnx7M
# 30320  ChIJ67HYNHcJz5QRvFhKeniPhPA
#
#                                              RAZAOSOCIAL
# 6                    REVCOM-REVENDA DE COMBUSTIVEIS LTDA
# 57                              AUTO POSTO BUDIÃƒO LTDA.
# 62     MACTRA COMÃ‰RCIO DE COMBUSTÃVEIS E LUBRIFICAN...
# 76              A. M. V. COMERCIO DE PETROLEO LTDA - EPP
# 82                 POSTO DE COMBUSTIVEIS IPUEIRINHA LTDA
# ...                                                  ...
# 30275                                POSTO REDE VAX LTDA
# 30284                REDE DE POSTOS MARAJO CARIRI 2 LTDA
# ...

# %%
# Save with a custom filename
place_razao_table.to_csv('raizen_places.csv', index=False)

# %%
# Save the table to JSON
place_razao_table.to_json('place_razao_table.json', orient='records', indent=2)
